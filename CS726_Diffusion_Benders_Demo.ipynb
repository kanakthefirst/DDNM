# %% [markdown]
# # Setup

# %%
# connect to a T4 GPU runtime
# uncomment and run only this cell from "Setup" and not the next one

# !git clone https://github.com/wyhuai/DDNM.git
# %mkdir /content/DDNM/hq_demo/data/pretrained
# %cd /content/DDNM/hq_demo/data/pretrained
# !wget https://openaipublic.blob.core.windows.net/diffusion/jul-2021/256x256_classifier.pt
# !wget https://openaipublic.blob.core.windows.net/diffusion/jul-2021/256x256_diffusion.pt
# !gdown https://drive.google.com/uc?id=1norNWWGYP3EZ_o05DmoW1ryKuKMmhlCX

# %cd /content/DDNM/hq_demo
# from PIL import Image
# img = lambda folder, i: Image.open(f"/content/DDNM/hq_demo/results/{folder}/{['Apy', 'final'][i]}/00000.png")

# %%
# connect to a T4 GPU runtime
# run this cell only if you have mounted your drive and have the DDNM folder at "MyDrive/" with the pre-trained weights downloaded

# %cd /content/drive/MyDrive/DDNM/hq_demo
from PIL import Image
img = lambda folder, i: Image.open(f"/content/drive/MyDrive/DDNM/hq_demo/results/{folder}/{['Apy', 'final'][i]}/00000.png")
# Out:
# /content/drive/MyDrive/DDNM/hq_demo

# %% [markdown]
# # Demo

# %%
# !pip install blobfile -q

# %%
# !python main.py --config confs/inet256.yml --path_y data/datasets/gts/inet256/323.png --class 323 --deg "colorization" --scale 1 -i butterfly

# %%
img('butterfly', 0)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=256x256>

# %%
img('butterfly', 1)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=256x256>

# %%
# !python main.py --config confs/inet256.yml --path_y data/datasets/gts/inet256/323.png --class 323 --deg "sr_averagepooling" --scale 4 -i butterfly_sr

# %%
img('butterfly_sr', 0)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=256x256>

# %%
img('butterfly_sr', 1)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=256x256>

# %%
# !python main.py --resize_y --config confs/inet256.yml --path_y data/datasets/gts/inet256/orange.png --class 950 --deg "sr_averagepooling" --scale 4 -i orange

# %%
img('orange', 0)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1024x256>

# %%
img('orange', 1)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1024x256>

# %%
# !python main.py --resize_y --config confs/inet256.yml --path_y data/datasets/gts/inet256/monarch.png --class 323 --deg "sr_averagepooling" --scale 4 --sigma_y 0.5 -i monarch

# %%
img('monarch', 0)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=564x396>

# %%
img('monarch', 1)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=564x396>

# %%
# !python main.py --resize_y --config confs/inet256.yml --path_y data/datasets/gts/inet256/bear.png --class 294 --deg "sr_averagepooling" --scale 4 -i bear

# %%
img('bear', 0)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1024x384>

# %%
img('bear', 1)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1024x384>

# %%
# !python main.py --config confs/face256.yml --path_y data/datasets/gts/face/orig_1.png --deg "mask_color_sr" --scale 8 -i face

# %%
img('face', 0)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=256x256>

# %%
img('face', 1)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=256x256>

# %%
# !python main.py --config confs/inet256.yml --path_y DIV2k/data/val/DIV2K_valid_LR_mild/0801x4m.png --class 145 --deg "sr_averagepooling" --scale 4 -i div2k-1

# %%
img('div2k-1', 0)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=508x336>

# %%
img('div2k-1', 1)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=508x336>
